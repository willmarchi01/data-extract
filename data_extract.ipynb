# %% [markdown]
# # Question 1 - Extracting Tesla Stock Data Using yfinance
#
# ---

# %%
# !pip install yfinance

# %%
import yfinance as yf

msft = yf.Ticker("TSLA")
msft_data = msft.history(period="5d")

# Display
msft_data.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-01-11 00:00:00-05:00  230.570007  230.929993  225.369995  227.220001
# 2024-01-12 00:00:00-05:00  220.080002  225.339996  217.149994  218.889999
# 2024-01-16 00:00:00-05:00  215.100006  223.490005  212.179993  219.910004
# 2024-01-17 00:00:00-05:00  214.860001  215.669998  212.009995  215.550003
# 2024-01-18 00:00:00-05:00  216.880005  217.449997  208.740005  211.880005
#
#                               Volume  Dividends  Stock Splits
# Date
# 2024-01-11 00:00:00-05:00  105873600        0.0           0.0
# 2024-01-12 00:00:00-05:00  122889000        0.0           0.0
# 2024-01-16 00:00:00-05:00  115355000        0.0           0.0
# 2024-01-17 00:00:00-05:00  103164400        0.0           0.0
# 2024-01-18 00:00:00-05:00  108262900        0.0           0.0

# %% [markdown]
# # Question 3 - Extracting GameStop Stock Data Using yfinance

# %%
import yfinance as yf

msft = yf.Ticker("GME")
msft_data = msft.history(period="5d")

# Display
msft_data.head()
# Out:
#                             Open   High    Low  Close   Volume  Dividends  \
# Date
# 2024-01-11 00:00:00-05:00  15.65  15.80  15.24  15.25  2992200        0.0
# 2024-01-12 00:00:00-05:00  15.30  15.62  14.73  14.75  2475500        0.0
# 2024-01-16 00:00:00-05:00  14.60  14.62  13.93  13.98  3581200        0.0
# 2024-01-17 00:00:00-05:00  13.86  14.11  13.71  14.08  2706200        0.0
# 2024-01-18 00:00:00-05:00  14.20  14.77  14.05  14.29  3896000        0.0
#
#                            Stock Splits
# Date
# 2024-01-11 00:00:00-05:00           0.0
# 2024-01-12 00:00:00-05:00           0.0
# 2024-01-16 00:00:00-05:00           0.0
# 2024-01-17 00:00:00-05:00           0.0
# 2024-01-18 00:00:00-05:00           0.0

# %% [markdown]
# # Question 5 - Tesla Stock and Revenue Dashboard

# %%
import yfinance as yf
import requests
from bs4 import BeautifulSoup
import plotly.express as px

# Function to get Tesla stock data
def get_stock_data(ticker, start_date, end_date):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    return stock_data

# Function to scrape Tesla revenue data
def scrape_revenue_data(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        # Add your scraping logic here
        # ...

# Example usage
ticker_symbol = "TSLA"
start_date = "2022-01-01"
end_date = "2024-01-01"
revenue_url = "https://example.com/tesla-revenue-page"

stock_data = get_stock_data(ticker_symbol, start_date, end_date)
revenue_data = scrape_revenue_data(revenue_url)

# Create an interactive plot for stock data
fig_stock = px.line(stock_data, x=stock_data.index, y="Close", title="Tesla Stock Data")

# Add your revenue data visualization here

# Show the plots
fig_stock.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Question 6 - GameStop Stock and Revenue Dashboard

# %%
import yfinance as yf
import requests
from bs4 import BeautifulSoup
import plotly.express as px

# Function to get GameStop stock data
def get_stock_data(ticker, start_date, end_date):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    return stock_data

# Function to scrape GameStop revenue data
def scrape_revenue_data(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        # Add your scraping logic here
        # ...

# Example usage
ticker_symbol_gme = "GME"
start_date_gme = "2022-01-01"
end_date_gme = "2024-01-01"
revenue_url_gme = "https://finance.yahoo.com/quote/TSLA/financials?p=TSLA"

stock_data_gme = get_stock_data(ticker_symbol_gme, start_date_gme, end_date_gme)
revenue_data_gme = scrape_revenue_data(revenue_url_gme)

# Create an interactive plot for GameStop stock data
fig_stock_gme = px.line(stock_data_gme, x=stock_data_gme.index, y="Close", title="GameStop Stock Data")

# Add your revenue data visualization here

# Show the plots
fig_stock_gme.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
